# %%
# importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
from sklearn.linear_model import LinearRegression

# %%
df_house = pd.read_csv('kc_house_data_NaN.csv')

# %%
df_house.head()
# Out:
#    Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 0           0  7129300520  20141013T000000  221900.0       3.0       1.00
# 1           1  6414100192  20141209T000000  538000.0       3.0       2.25
# 2           2  5631500400  20150225T000000  180000.0       2.0       1.00
# 3           3  2487200875  20141209T000000  604000.0       4.0       3.00
# 4           4  1954400510  20150218T000000  510000.0       3.0       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         1180      5650     1.0           0  ...      7        1180
# 1         2570      7242     2.0           0  ...      7        2170
# 2          770     10000     1.0           0  ...      6         770
# 3         1960      5000     1.0           0  ...      7        1050
# 4         1680      8080     1.0           0  ...      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
# Display the Datatypes
df_house.dtypes
# Out:
# Unnamed: 0         int64
# id                 int64
# date              object
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df_house.describe()
# Out:
#         Unnamed: 0            id         price      bedrooms     bathrooms  \
# count  21613.00000  2.161300e+04  2.161300e+04  21600.000000  21603.000000
# mean   10806.00000  4.580302e+09  5.400881e+05      3.372870      2.115736
# std     6239.28002  2.876566e+09  3.671272e+05      0.926657      0.768996
# min        0.00000  1.000102e+06  7.500000e+04      1.000000      0.500000
# 25%     5403.00000  2.123049e+09  3.219500e+05      3.000000      1.750000
# 50%    10806.00000  3.904930e+09  4.500000e+05      3.000000      2.250000
# 75%    16209.00000  7.308900e+09  6.450000e+05      4.000000      2.500000
# max    21612.00000  9.900000e+09  7.700000e+06     33.000000      8.000000
#
#         sqft_living      sqft_lot        floors    waterfront          view  \
# count  21613.000000  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean    2079.899736  1.510697e+04      1.494309      0.007542      0.234303
# ...

# %%
#Drop the columns and use descibe method
df_house.drop(['Unnamed: 0','id'],axis=1,inplace=True)
df_house.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21600.000000  21603.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.372870      2.115736   2079.899736  1.510697e+04
# std    3.671272e+05      0.926657      0.768996    918.440897  4.142051e+04
# min    7.500000e+04      1.000000      0.500000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       1.494309      0.007542      0.234303      3.409430      7.656873
# ...

# %%
df_house.isnull().sum()
# Out:
# date              0
# price             0
# bedrooms         13
# bathrooms        10
# sqft_living       0
# sqft_lot          0
# floors            0
# waterfront        0
# view              0
# condition         0
# grade             0
# sqft_above        0
# sqft_basement     0
# yr_built          0
# yr_renovated      0
# zipcode           0
# lat               0
# long              0
# sqft_living15     0
# sqft_lot15        0
# dtype: int64

# %%
print("number of NaN values for the column bedrooms :", df_house['bedrooms'].isnull().sum())
print("number of NaN values for the column bathrooms :", df_house['bathrooms'].isnull().sum())
# Out:
# number of NaN values for the column bedrooms : 13
# number of NaN values for the column bathrooms : 10

# %%
mean = df_house['bedrooms'].mean()
df_house['bedrooms'].replace(np.nan, mean, inplace =True)

# %%
mean1 = df_house['bathrooms'].mean()
df_house['bathrooms'].replace(np.nan, mean1, inplace =True)

# %%
print("number of NaN values for the column bedrooms :", df_house['bedrooms'].isnull().sum())
print("number of NaN values for the column bathrooms :", df_house['bathrooms'].isnull().sum())
# Out:
# number of NaN values for the column bedrooms : 0
# number of NaN values for the column bathrooms : 0

# %%
df_house.head(10)
# Out:
#               date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  20141013T000000   221900.0       3.0       1.00         1180      5650
# 1  20141209T000000   538000.0       3.0       2.25         2570      7242
# 2  20150225T000000   180000.0       2.0       1.00          770     10000
# 3  20141209T000000   604000.0       4.0       3.00         1960      5000
# 4  20150218T000000   510000.0       3.0       2.00         1680      8080
# 5  20140512T000000  1225000.0       4.0       4.50         5420    101930
# 6  20140627T000000   257500.0       3.0       2.25         1715      6819
# 7  20150115T000000   291850.0       3.0       1.50         1060      9711
# 8  20150415T000000   229500.0       3.0       1.00         1780      7470
# 9  20150312T000000   323000.0       3.0       2.50         1890      6560
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     1.0           0     0          3      7        1180              0
# ...

# %%
# no of houses with unique floor values
floor_counts = df_house['floors'].value_counts().to_frame()
floor_counts
# Out:
#      floors
# 1.0   10680
# 2.0    8241
# 1.5    1910
# 3.0     613
# 2.5     161
# 3.5       8

# %%
# make a boxplot
sns.boxplot(x = 'waterfront', y ='price', data = df_house)
# Out:
# <AxesSubplot:xlabel='waterfront', ylabel='price'>

# %%
# make a Regression plot
sns.regplot(x='sqft_above', y='price', data=df_house)
# Out:
# <AxesSubplot:xlabel='sqft_above', ylabel='price'>

# %%
df_house.corr()['price'].sort_values()
# Out:
# zipcode         -0.053203
# long             0.021626
# condition        0.036362
# yr_built         0.054012
# sqft_lot15       0.082447
# sqft_lot         0.089661
# yr_renovated     0.126434
# floors           0.256794
# waterfront       0.266369
# lat              0.307003
# bedrooms         0.308797
# sqft_basement    0.323816
# view             0.397293
# bathrooms        0.525738
# sqft_living15    0.585379
# sqft_above       0.605567
# grade            0.667434
# sqft_living      0.702035
# price            1.000000
# Name: price, dtype: float64

# %%
x = df_house[['long']]
y = df_house['price']
lm = LinearRegression()
lm.fit(x,y)
lm.score(x,y)
# Out:
# 0.00046769430149007363

# %%
# linear regression for sqft_living
x = df_house[['sqft_living']]
y = df_house['price']
lm = LinearRegression()
lm.fit(x,y)
lm.score(x,y)
# Out:
# 0.4928532179037931

# %%
# Multiple feature's linear regression
features =df_house[["floors", "waterfront","lat" ,"bedrooms" ,"sqft_basement" ,"view" ,"bathrooms","sqft_living15","sqft_above","grade","sqft_living"]]
y = df_house['price']
lm.fit(features,y)
lm.score(features,y)
# Out:
# 0.6576951666037502

# %%
Input=[('scale',StandardScaler()),('polynomial', PolynomialFeatures(include_bias=False)),('model',LinearRegression())]

# %%
# Question 8
pipe=Pipeline(Input)
features = features.astype(float)
pipe.fit(features,y)
pipe.score(features,y)
# Out:
# 0.7513404101380663

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

# %%
features =["floors", "waterfront","lat" ,"bedrooms" ,"sqft_basement" ,"view" ,"bathrooms","sqft_living15","sqft_above","grade","sqft_living"]    
X = df_house[features]
Y = df_house['price']

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.15, random_state=1)


print("number of test samples:", x_test.shape[0])
print("number of training samples:",x_train.shape[0])
# Out:
# number of test samples: 3242
# number of training samples: 18371

# %%
# Ridge Regression 
from sklearn.linear_model import Ridge

# %%
rige = Ridge(alpha = 0.1)
rige.fit(x_train,y_train)
rige.score(x_test,y_test)
# Out:
# 0.6478759163939112

# %%
# polynomial Transformantion and fit using ridge regression
pr = PolynomialFeatures(degree=2)
x_train_pr= pr.fit_transform(x_train)
x_test_pr = pr.fit_transform(x_test)
rige = Ridge(alpha = 0.1)
rige.fit(x_train_pr,y_train)
rige.score(x_test_pr,y_test)
# Out:
# 0.7002744259992868
